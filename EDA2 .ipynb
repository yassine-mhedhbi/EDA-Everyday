# %%
import pandas as pd
import numpy as np
import pycountry 
import pycountry_convert as pc
import plotly_express
import plotly

# %%
# !kaggle competitions download -c covid19-global-forecasting-week-4
# Out:
# Downloading covid19-global-forecasting-week-4.zip to /home/ymhedh/Documents/Covid-19
# 100%|████████████████████████████████████████| 248k/248k [00:00<00:00, 2.36MB/s]
# 100%|████████████████████████████████████████| 248k/248k [00:00<00:00, 2.35MB/s]
